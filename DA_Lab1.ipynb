# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_csv('10_patient_dataset (3).csv')
data.tail(2)
data['D-Dimer Test Level']
data[5:8]
data.shape
# Out:
# (17, 10)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Patient ID', 'Diabetes Test Type',
#        'Glucose level recorded', 'D-Dimer Test Level',
#        'Systolic Blood Pressure (mm Hg)', 'Diastolic Blood Pressure (mm Hg)',
#        'Body Temperature (°F)', 'Oxygen Level (Spo2)', 'Chest Congestion (%)'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Timestamp                           17
# Patient ID                          17
# Diabetes Test Type                   1
# Glucose level recorded              10
# D-Dimer Test Level                   7
# Systolic Blood Pressure (mm Hg)     12
# Diastolic Blood Pressure (mm Hg)     6
# Body Temperature (°F)               10
# Oxygen Level (Spo2)                  7
# Chest Congestion (%)                 6
# dtype: int64

# %%
data['Diastolic Blood Pressure (mm Hg)'].unique()
# Out:
# array([78, 81, 84, 82, 80, 79])

# %%
data1 = data.drop(['Diabetes Test Type', 'Chest Congestion (%)'], axis=1)
data1.head()
# Out:
#   Timestamp  Patient ID  Glucose level recorded  D-Dimer Test Level  \
# 0    1.2.22        1000                   125.0                0.45
# 1    2.2.22        1001                   124.0                0.46
# 2    3.2.22        1002                   124.6                0.50
# 3    4.2.22        1003                   124.2                0.47
# 4    5.2.22        1004                   123.9                0.42
#
#    Systolic Blood Pressure (mm Hg)  Diastolic Blood Pressure (mm Hg)  \
# 0                             99.0                                78
# 1                            105.0                                81
# 2                            106.0                                84
# 3                            111.0                                82
# 4                            100.0                                80
#
#    Body Temperature (°F)  Oxygen Level (Spo2)
# 0                   98.0                   99
# 1                  103.0                   96
# ...

# %%
corelation = data.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Diastolic Blood Pressure (mm Hg)', y='Systolic Blood Pressure (mm Hg)', hue='Patient ID', data=data)

# %%
sns.distplot(data['Oxygen Level (Spo2)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='Glucose level recorded', data=data)

# %%
data.dropna()
# Out:
#    Timestamp  Patient ID           Diabetes Test Type  Glucose level recorded  \
# 0     1.2.22        1000  Fasting Plasma Glucose Test                  125.00
# 1     2.2.22        1001  Fasting Plasma Glucose Test                  124.00
# 2     3.2.22        1002  Fasting Plasma Glucose Test                  124.60
# 3     4.2.22        1003  Fasting Plasma Glucose Test                  124.20
# 4     5.2.22        1004  Fasting Plasma Glucose Test                  123.90
# 5     6.2.22        1005  Fasting Plasma Glucose Test                  123.80
# 6     7.2.22        1006  Fasting Plasma Glucose Test                  122.00
# 7    11.2.22        1007  Fasting Plasma Glucose Test                  122.61
# 8    21.2.22        1008  Fasting Plasma Glucose Test                  122.63
# 9    27.2.22        1009  Fasting Plasma Glucose Test                  122.80
# 10   30.2.22        1010  Fasting Plasma Glucose Test                  125.00
# ...

# %%
data2 = pd.read_csv('10_patient_dataset (4).csv')
data2.shape
# Out:
# (17, 10)

# %%
data2.dropna()
# Out:
#    Timestamp  Patient ID           Diabetes Test Type  Glucose level recorded  \
# 0     1.2.22        1000  Fasting Plasma Glucose Test                  125.00
# 1     2.2.22        1001  Fasting Plasma Glucose Test                  124.00
# 4     5.2.22        1004  Fasting Plasma Glucose Test                  102.30
# 5     6.2.22        1005  Fasting Plasma Glucose Test                  123.80
# 7    11.2.22        1007  Fasting Plasma Glucose Test                  122.61
# 8    21.2.22        1008  Fasting Plasma Glucose Test                  144.00
# 9    27.2.22        1009  Fasting Plasma Glucose Test                  122.80
# 10   30.2.22        1010  Fasting Plasma Glucose Test                  125.00
# 12   41.2.22        1012  Fasting Plasma Glucose Test                  124.60
# 13   47.2.22        1013  Fasting Plasma Glucose Test                  122.00
# 14   49.2.22        1014  Fasting Plasma Glucose Test                  100.80
# ...

# %%
sns.boxplot(x='Glucose level recorded', data=data2)
